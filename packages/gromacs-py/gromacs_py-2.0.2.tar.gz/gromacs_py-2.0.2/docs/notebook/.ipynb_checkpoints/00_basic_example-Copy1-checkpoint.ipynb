# %% [markdown]
# # *Gromacs_py* basic example
#
# Here is an example of a short simulation of the SH3 domain of phospholipase C$\gamma$1.
# Five successive steps are used:
#
# 1. Topologie creation using ``GmxSys.prepare_top()``.
# 2. Minimisation of the structure using ``GmxSys.em_2_steps()``.
# 3. Solvation of the system using ``GmxSys.solvate_add_ions()``.
# 4. Equilibration of the system using ``GmxSys.em_equi_three_step_iter_error()``.
# 5. Production run using ``GmxSys.production()``.
#
# ### Import

# %%
import sys
import os
import urllib.request  
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Gromacs_py import
from gromacs_py import gmx
print(gmx.__file__)
# Out:
# /Users/smurail/Documents/Code/gromacs_py/gromacs_py/gmx.py

# %% [markdown]
# ## Simulation setup

# %%
# Setup data location
DATA_OUT = 'data_sim'
PDB_ID = '1Y0M'

# System Setup
vsite='none'
ion_C = 0.15
sys_top_folder = os.path.join(DATA_OUT, 'sys_top')

# Energy Minimisation
em_folder = os.path.join(DATA_OUT, 'em')
em_sys_folder = os.path.join(DATA_OUT, 'sys_em')
em_step_number = 5000

# Equillibration
equi_folder = os.path.join(DATA_OUT, 'sys_equi')
HA_time = 0.5
CA_time = 1.0
CA_LOW_time = 2.0

dt_HA = 0.005
dt = 0.005

HA_step = 1000 * HA_time / dt_HA
CA_step = 1000 * CA_time / dt
CA_LOW_step = 1000 * CA_LOW_time / dt

# Production
prod_folder = os.path.join(DATA_OUT, 'sys_prod')
prod_time = 10.0

prod_step = 1000 * prod_time / dt

# %% [markdown]
# ## Get PDB file from the ``rcsb.org`` website

# %%
os.makedirs(DATA_OUT, exist_ok = True)

raw_pdb = urllib.request.urlretrieve('http://files.rcsb.org/download/{}.pdb'.format(PDB_ID),
                           '{}/{}.pdb'.format(DATA_OUT, PDB_ID))

# %% [markdown]
# ### Define the simulation system

# %%
md_sys = gmx.GmxSys(name=PDB_ID, coor_file=raw_pdb[0])
md_sys.display()
# Out:
# name         : 1Y0M
# coor_file    : data_sim/1Y0M.pdb
# nt           : 0
# ntmpi        : 0
# sys_history  : 0

# %%
view = md_sys.view_coor()
view.add_representation(selection='protein', repr_type='ball+stick')
view
# Out:
# NGLWidget()

# %% [markdown]
# ## Create topology:

# %%
md_sys.prepare_top(out_folder=os.path.join(DATA_OUT, 'prot_top'), vsite=vsite, ff='amber99sb-ildn')
md_sys.create_box(dist=1.0, box_type="dodecahedron", check_file_out=True)

# %% [markdown]
# ## Energy minimisation

# %%
md_sys.em_2_steps(out_folder=em_folder,
                  no_constr_nsteps=em_step_number,
                  constr_nsteps=em_step_number,
                  posres="",
                  create_box_flag=False)

# %% [markdown]
# ## Plot energy:

# %%
ener_pd_1 = md_sys.sys_history[-1].get_ener(selection_list=['Potential'])
ener_pd_2 = md_sys.get_ener(selection_list=['Potential'])

ener_pd_1['label'] = 'no bond constr'
ener_pd_2['label'] = 'bond constr'

ener_pd = pd.concat([ener_pd_1, ener_pd_2])

ener_pd.time = np.arange(len(ener_pd))

#ax = ener_pd.plot(x='time')
ax = sns.lineplot(x="time", y="Potential",
             hue="label",
             data=ener_pd)
ax.set_xlabel('step')
ax.set_ylabel('energy (KJ/mol)')
# Out:
# gmx energy -f data_sim/em/Init_em_1Y0M.edr -o tmp.xvg
# gmx energy -f data_sim/em/1Y0M.edr -o tmp.xvg
# Text(0, 0.5, 'energy (KJ/mol)')

# %% [markdown]
# ## Solvation (water and $Na^{+} Cl^{-}$)

# %%
md_sys.solvate_add_ions(out_folder=sys_top_folder,
                        ion_C=ion_C)
md_sys.display()
# Out:
# name         : 1Y0M
# sim_name     : 1Y0M
# coor_file    : data_sim/sys_top/1Y0M_water_ion.gro
# top_file     : data_sim/sys_top/1Y0M_water_ion.top
# tpr          : data_sim/em/1Y0M.tpr
# mdp          : data_sim/em/1Y0M.mdp
# xtc          : data_sim/em/1Y0M.trr
# edr          : data_sim/em/1Y0M.edr
# log          : data_sim/em/1Y0M.log
# nt           : 0
# ntmpi        : 0
# sys_history  : 4

# %% [markdown]
# ## System minimisation and equilibration

# %%
md_sys.em_equi_three_step_iter_error(out_folder=equi_folder,
                                     no_constr_nsteps=em_step_number,
                                     constr_nsteps=em_step_number,
                                     nsteps_HA=HA_step,
                                     nsteps_CA=CA_step,
                                     nsteps_CA_LOW=CA_LOW_step,
                                     dt=dt, dt_HA=dt_HA,
                                     vsite=vsite)

# %% [markdown]
# ### Display history and plot temperature

# %%
md_sys.display_history()
# Out:
# State -10:
#
# name         : 1Y0M
# coor_file    : data_sim/prot_top/1Y0M_pdb2gmx_box.pdb
# top_file     : data_sim/prot_top/1Y0M_pdb2gmx.top
# nt           : 0
# ntmpi        : 0
# sys_history  : 0
#
# State -9:
#
# name         : 1Y0M
# sim_name     : Init_em_1Y0M
# coor_file    : data_sim/sys_equi/sys_em/Init_em_1Y0M.gro
# top_file     : data_sim/prot_top/1Y0M_pdb2gmx.top
# tpr          : data_sim/sys_equi/sys_em/Init_em_1Y0M.tpr
# mdp          : data_sim/sys_equi/sys_em/Init_em_1Y0M.mdp
# xtc          : data_sim/sys_equi/sys_em/Init_em_1Y0M.trr
# edr          : data_sim/sys_equi/sys_em/Init_em_1Y0M.edr
# log          : data_sim/sys_equi/sys_em/Init_em_1Y0M.log
# nt           : 0
# ntmpi        : 0
# sys_history  : 0
#
# State -8:
#
# name         : 1Y0M
# sim_name     : 1Y0M
# coor_file    : data_sim/sys_equi/sys_em/1Y0M_compact.pdb
# top_file     : data_sim/prot_top/1Y0M_pdb2gmx.top
# tpr          : data_sim/sys_equi/sys_em/1Y0M.tpr
# mdp          : data_sim/sys_equi/sys_em/1Y0M.mdp
# xtc          : data_sim/sys_equi/sys_em/1Y0M.trr
# edr          : data_sim/sys_equi/sys_em/1Y0M.edr
# log          : data_sim/sys_equi/sys_em/1Y0M.log
# nt           : 0
# ntmpi        : 0
# sys_history  : 0
#
# State -7:
#
# name         : 1Y0M
# sim_name     : equi_HA_1Y0M
# coor_file    : data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.gro
# top_file     : data_sim/prot_top/1Y0M_pdb2gmx.top
# tpr          : data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.tpr
# mdp          : data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.mdp
# xtc          : data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.xtc
# edr          : data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.edr
# log          : data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.log
# nt           : 0
# ntmpi        : 0
# sys_history  : 0
#
# State -6:
#
# name         : 1Y0M
# sim_name     : equi_CA_1Y0M
# coor_file    : data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.gro
# top_file     : data_sim/prot_top/1Y0M_pdb2gmx.top
# tpr          : data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.tpr
# mdp          : data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.mdp
# xtc          : data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.xtc
# edr          : data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.edr
# log          : data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.log
# nt           : 0
# ntmpi        : 0
# sys_history  : 0
#
# State -5:
#
# name         : 1Y0M
# sim_name     : equi_CA_LOW_1Y0M
# coor_file    : data_sim/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.gro
# top_file     : data_sim/prot_top/1Y0M_pdb2gmx.top
# tpr          : data_sim/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.tpr
# mdp          : data_sim/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.mdp
# xtc          : data_sim/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.xtc
# edr          : data_sim/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.edr
# log          : data_sim/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.log
# nt           : 0
# ntmpi        : 0
# sys_history  : 0
#
# State -4:
#
# name         : 1Y0M
# sim_name     : Init_em_1Y0M
# coor_file    : data_sim/sys_equi/sys_em/Init_em_1Y0M.gro
# top_file     : data_sim/prot_top/1Y0M_pdb2gmx.top
# tpr          : data_sim/sys_equi/sys_em/Init_em_1Y0M.tpr
# mdp          : data_sim/sys_equi/sys_em/Init_em_1Y0M.mdp
# xtc          : data_sim/sys_equi/sys_em/Init_em_1Y0M.trr
# edr          : data_sim/sys_equi/sys_em/Init_em_1Y0M.edr
# log          : data_sim/sys_equi/sys_em/Init_em_1Y0M.log
# nt           : 0
# ntmpi        : 0
# sys_history  : 0
#
# State -3:
#
# name         : 1Y0M
# sim_name     : 1Y0M
# coor_file    : data_sim/sys_equi/sys_em/1Y0M_compact.pdb
# top_file     : data_sim/prot_top/1Y0M_pdb2gmx.top
# tpr          : data_sim/sys_equi/sys_em/1Y0M.tpr
# mdp          : data_sim/sys_equi/sys_em/1Y0M.mdp
# xtc          : data_sim/sys_equi/sys_em/1Y0M.trr
# edr          : data_sim/sys_equi/sys_em/1Y0M.edr
# log          : data_sim/sys_equi/sys_em/1Y0M.log
# nt           : 0
# ntmpi        : 0
# sys_history  : 0
#
# State -2:
#
# name         : 1Y0M
# sim_name     : equi_HA_1Y0M
# coor_file    : data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.gro
# top_file     : data_sim/prot_top/1Y0M_pdb2gmx.top
# tpr          : data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.tpr
# mdp          : data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.mdp
# xtc          : data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.xtc
# edr          : data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.edr
# log          : data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.log
# nt           : 0
# ntmpi        : 0
# sys_history  : 0
#
# State -1:
#
# name         : 1Y0M
# sim_name     : equi_CA_1Y0M
# coor_file    : data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.gro
# top_file     : data_sim/prot_top/1Y0M_pdb2gmx.top
# tpr          : data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.tpr
# mdp          : data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.mdp
# xtc          : data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.xtc
# edr          : data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.edr
# log          : data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.log
# nt           : 0
# ntmpi        : 0
# sys_history  : 0

# %%
ener_pd_1 = md_sys.sys_history[-2].get_ener(selection_list=['Volume'])
ener_pd_2 = md_sys.sys_history[-1].get_ener(selection_list=['Volume'])
ener_pd_3 = md_sys.get_ener(selection_list=['Volume'])

ener_pd_1['label'] = 'HA_constr'
ener_pd_2['label'] = 'CA_constr'
ener_pd_2.time = ener_pd_2.time + ener_pd_1.time.max()
ener_pd_3['label'] = 'CA_LOW_constr'
ener_pd_3.time = ener_pd_3.time + ener_pd_2.time.max()

ener_pd = pd.concat([ener_pd_1, ener_pd_2, ener_pd_3])
# Out:
# gmx energy -f data_sim/sys_equi/sys_equi/00_equi_HA/equi_HA_1Y0M.edr -o tmp.xvg
# gmx energy -f data_sim/sys_equi/sys_equi/01_equi_CA/equi_CA_1Y0M.edr -o tmp.xvg
# gmx energy -f data_sim/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.edr -o tmp.xvg

# %%
ax = sns.lineplot(x="time", y="Volume",
                  hue="label",
                  data=ener_pd)

ax.set_xlabel('time (ps)')
ax.set_ylabel('Volume ($Å^3$)')
#ax.set_ylim(305, 322)
# Out:
# Text(0, 0.5, 'Volume ($Å^3$)')

# %%
view = md_sys.view_traj()
view.add_representation(selection='protein', repr_type='ball+stick')
view
# Out:
# NGLWidget(count=81)

# %% [markdown]
# ## Production

# %%
md_sys.production(out_folder=prod_folder,
                  nsteps=prod_step,
                  dt=dt, vsite=vsite)
# Out:
# gmx grompp -f prod_1Y0M.mdp -c ../sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.gro -r ../sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.gro -p ../prot_top/1Y0M_pdb2gmx.top -po out_prod_1Y0M.mdp -o prod_1Y0M.tpr -maxwarn 0
# The following command could not be executed correctly :
# gmx grompp -f prod_1Y0M.mdp -c ../sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.gro -r ../sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.gro -p ../prot_top/1Y0M_pdb2gmx.top -po out_prod_1Y0M.mdp -o prod_1Y0M.tpr -maxwarn 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-840ee1b3cd04> in <module>
# ----> 1 md_sys.production(out_folder=prod_folder,
#       2                   nsteps=prod_step,
#       3                   dt=dt, vsite=vsite)
#
# ~/Documents/Code/gromacs_py/gromacs_py/gmx.py in production(self, out_folder, name, nsteps, dt, maxwarn, monitor, vsite, **mdp_options)
#    4278
#    4279         mdp_options.update({'nsteps': int(nsteps), 'dt': dt, 'define': ''})
# -> 4280         self.run_md_sim(out_folder=out_folder, mdp_template=equi_template_mdp,
#    4281                         mdp_options=mdp_options, name="prod_" + name,
#    4282                         monitor=monitor, maxwarn=maxwarn)
#
# ~/Documents/Code/gromacs_py/gromacs_py/gmx.py in run_md_sim(self, out_folder, name, mdp_template, mdp_options, pdb_restr, maxwarn, monitor)
#    3907         self.sim_name = name
#    3908         self.add_mdp(mdp_template=mdp_template, mdp_options=mdp_options)
# -> 3909         self.add_tpr(name=name, r=pdb_restr, maxwarn=maxwarn)
#    3910         self.run_simulation(monitor=monitor)
#    3911
#
# ~/Documents/Code/gromacs_py/gromacs_py/gmx.py in add_tpr(self, name, r, po, folder_out, check_file_out, **grompp_options)
#    3702         cmd_tpr.define_env(my_env=os.environ.update({'GMXLIB': GMXLIB_var}))
#    3703
# -> 3704         cmd_tpr.run(display=False)
#    3705
#    3706         self.tpr = tpr_out
#
# ~/opt/miniconda3/envs/docking/lib/python3.8/site-packages/os_command_py/os_command.py in run(self, com_input, display, out_data)
#     442         print("The following command could not be executed correctly :")
#     443         self.display()
# --> 444         raise RuntimeError(
#     445             'Following Command Fails : {} \n Ret code = {} \n {} \n {}'.format(
#     446                 " ".join(self.cmd),
#
# RuntimeError: Following Command Fails : /Users/smurail/Documents/Software/gromacs/local_2016.4/bin/gmx grompp -f prod_1Y0M.mdp -c ../sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.gro -r ../sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.gro -p ../prot_top/1Y0M_pdb2gmx.top -po ./out_prod_1Y0M.mdp -o prod_1Y0M.tpr -maxwarn 0
#  Ret code = 1
#  turning H bonds into constraints...
#
#                        :-) GROMACS - gmx grompp, 2016.4 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov  Herman J.C. Berendsen    Par Bjelkmar
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra    Gerrit Groenhof
#  Christoph Junghans   Anca Hamuraru    Vincent Hindriksen Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul   Magnus Lundborg   Pieter Meulenhoff    Erik Marklund
#    Teemu Murtola       Szilard Pall       Sander Pronk      Roland Schulz
#   Alexey Shvetsov     Michael Shirts     Alfons Sijbers     Peter Tieleman
#   Teemu Virolainen  Christian Wennberg    Maarten Wolf
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2017, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2016.4
# Executable:   /Users/smurail/Documents/Software/gromacs/local_2016.4/bin/gmx
# Data prefix:  /Users/smurail/Documents/Software/gromacs/local_2016.4
# Working dir:  /Users/smurail/Documents/Code/gromacs_py/docs/notebook/data_sim/sys_prod
# Command line:
#   gmx grompp -f prod_1Y0M.mdp -c ../sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.gro -r ../sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.gro -p ../prot_top/1Y0M_pdb2gmx.top -po ./out_prod_1Y0M.mdp -o prod_1Y0M.tpr -maxwarn 0
#
# Ignoring obsolete mdp entry 'title'
#
# Back Off! I just backed up ./out_prod_1Y0M.mdp to ./#out_prod_1Y0M.mdp.2#
# Setting the LD random seed to -619582139
# Generated 2211 of the 2211 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
# Generated 2211 of the 2211 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'Protein_chain_A'
#
# NOTE 1 [file 1Y0M_pdb2gmx.top, line 19]:
#   System has non-zero total charge: -0.139997
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
#
# -------------------------------------------------------
# Program:     gmx grompp, version 2016.4
# Source file: src/gromacs/gmxpreprocess/grompp.cpp (line 612)
#
# Fatal error:
# number of coordinates in coordinate file
# (../sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_1Y0M.gro, 15583)
#              does not match topology (../prot_top/1Y0M_pdb2gmx.top, 1064)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------

# %%
ener_temp = md_sys.get_ener(selection_list=['T-Protein', 'T-non-Protein'])

ax = ener_temp.plot(x='time')
ax.set_xlabel('time (ps)')
ax.set_ylabel('Temperature (K)')

# %%
md_sys.sys_history[-2].

# %%
import simpletraj

# %%
import nglview as nv

view = nv.NGLWidget(nv.SimpletrajTrajectory(md_sys.sys_history[-1].xtc, md_sys.coor_file))
view
